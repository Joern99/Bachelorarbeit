# %% [markdown]
# Kendall W über die Dimensionen

# %% [markdown]
# # =====================================================================
# # 0. Setup: Pakete und Daten (HUMAN)
# # =====================================================================

# %%
# =====================================================================
# Pakete
# =====================================================================
library(dplyr)
library(tidyr)
library(ggplot2)
library(reshape2)
library(knitr)
library(irr)
library(readxl)
library(xtable)


# =====================================================================
# 0. Daten einlesen
# =====================================================================
setwd("/Users/joern.ahlert/Desktop/Bachelorarbeit")

df_raw <- read_excel(
  path = "technische Umsetzung/Diagramme/Plausibilitätsbewertung von LLM Antworten2.xlsx"
)

# Beispiele:
# exclude_rows <- NULL        # Keine Zeile weglassen
# exclude_rows <- 3           # Nur Zeile 3 weglassen
# exclude_rows <- c(1, 5, 7)  # Zeilen 1, 5 und 7 weglassen

exclude_rows <- NULL  # <- HIER EINGEBEN, welche Zeile(n) weggelassen werden sollen

# Zeilen entfernen, falls angegeben
if (!is.null(exclude_rows)) {
  cat("Weglassen von Zeile(n):", exclude_rows, "\n")
  cat("Anzahl Zeilen vorher:", nrow(df_raw), "\n")
  df_raw <- df_raw[-exclude_rows, ]
  cat("Anzahl Zeilen nachher:", nrow(df_raw), "\n\n")
} else {
  cat("Keine Zeilen werden weggelassen.\n\n")
}


View(df_raw)
# =====================================================================
# 1. Antworttexte in numerische Scores umkodieren
# =====================================================================
likert_map <- c(
  "Trifft überhaupt nicht zu" = 1,
  "Trifft eher nicht zu"      = 2,
  "Trifft teilweise zu"       = 3,
  "Trifft eher zu"            = 4,
  "Trifft voll und ganz zu"   = 5
)

plaus_map <- c(
  "Unmöglich – Die Antwort widerspricht der Logik oder dem Kontext vollständig" = 1,
  "Technisch möglich – Theoretisch denkbar, aber extrem unwahrscheinlich"      = 2,
  "Plausibel – Könnte zutreffen, ist aber nicht der Normalfall"                = 3,
  "Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung"            = 4,
  "Sehr wahrscheinlich – Sehr überzeugend; so würde ein Experte antworten"     = 5
)


meta_cols <- c("ID", "Startzeit", "Fertigstellungszeit",
               "E-Mail", "Name", "Zeitpunkt der letzten Änderung")
item_cols <- setdiff(names(df_raw), meta_cols)

plaus_cols   <- grep("Wie plausibel ist die Antwort", item_cols, value = TRUE)
quality_cols <- setdiff(item_cols, plaus_cols)

df_num <- df_raw |>
  mutate(
    across(all_of(quality_cols), ~ likert_map[.x]),
    across(all_of(plaus_cols),   ~ plaus_map[.x])
  )

# =====================================================================
# 2. Items Fragen und Dimensionen zuordnen
# =====================================================================
n_fragen <- 8
n_items_pro_frage <- length(item_cols) / n_fragen

frage_nr <- rep(1:n_fragen, each = n_items_pro_frage)

item_info <- data.frame(
  Spalte   = item_cols,
  Frage_Nr = frage_nr
)

item_info <- item_info |>
  mutate(
    Dimension = case_when(
      grepl("relevanten Informationen aus dem Kontext", Spalte) ~ "Kontextverständnis",
      grepl("korrektes Verständnis des Kontexts", Spalte)       ~ "Kontextverständnis",
      grepl("statt allgemeinem Wissen", Spalte)                 ~ "Kontextverständnis",
      
      grepl("widersprechen sich nicht", Spalte)                 ~ "Kohärenz",
      grepl("Schlussfolgerungen in der Antwort", Spalte)        ~ "Kohärenz",
      grepl("Gedankenführung der Antwort", Spalte)              ~ "Kohärenz",
      
      grepl("Detailtiefe der Antwort", Spalte)                  ~ "Angemessenheit",
      grepl("adressiert alle wesentlichen Aspekte", Spalte)     ~ "Angemessenheit",
      
      grepl("Wie plausibel ist die Antwort", Spalte)            ~ "Gesamtplausibilität",
      TRUE ~ NA_character_
    )
  )

# =====================================================================
# 3. Long-Format bauen
# =====================================================================
df_long <- df_num |>
  mutate(Episode = row_number()) |>
  pivot_longer(
    cols      = all_of(item_cols),
    names_to  = "Spalte",
    values_to = "Score"
  ) |>
  left_join(item_info, by = "Spalte")

# =====================================================================
# 4. Aggregation ins LLM-Format
# =====================================================================
df_human <- df_long |>
  group_by(Episode, Frage_Nr, Dimension) |>
  summarise(Score = mean(Score, na.rm = TRUE), .groups = "drop") |>
  pivot_wider(
    names_from  = Dimension,
    values_from = Score
  ) |>
  rename(
    Kontextverständnis_Score  = Kontextverständnis,
    Kohärenz_Score            = Kohärenz,
    Angemessenheit_Score      = Angemessenheit,
    Gesamtplausibilität_Score = Gesamtplausibilität
  ) |>
  arrange(Episode, Frage_Nr)

View(df_human)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# Loading required package: lpSolve
# Keine Zeilen werden weggelassen.
#    ID Startzeit           Fertigstellungszeit E-Mail    Name
# 1   4 2025-12-09 18:32:40 2025-12-09 19:36:22 anonymous NA
# 2   5 2025-12-11 10:43:43 2025-12-11 10:53:23 anonymous NA
# 3   6 2025-12-14 20:33:59 2025-12-15 22:14:01 anonymous NA
# 4   7 2025-12-17 14:35:27 2025-12-17 14:55:00 anonymous NA
# 5   8 2025-12-17 14:44:04 2025-12-17 15:10:55 anonymous NA
# 6   9 2025-12-17 16:01:47 2025-12-17 16:19:21 anonymous NA
# 7  10 2025-12-17 17:03:13 2025-12-17 17:52:34 anonymous NA
# 8  11 2025-12-19 20:29:25 2025-12-19 21:27:48 anonymous NA
# 9  12 2025-12-20 00:57:38 2025-12-20 01:10:42 anonymous NA
# 10 13 2025-12-20 10:55:13 2025-12-20 11:34:13 anonymous NA
#    Zeitpunkt der letzten Änderung
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
#    Die Antwort erfasst die relevanten Informationen aus dem Kontext.
# 1  Trifft voll und ganz zu
# 2  Trifft eher zu
# 3  Trifft teilweise zu
# 4  Trifft voll und ganz zu
# 5  Trifft voll und ganz zu
# 6  Trifft eher nicht zu
# 7  Trifft voll und ganz zu
# 8  Trifft voll und ganz zu
# 9  Trifft eher nicht zu
# 10 Trifft teilweise zu
#    Die Antwort zeigt ein korrektes Verständnis des Kontexts.
# 1  Trifft voll und ganz zu
# 2  Trifft eher zu
# 3  Trifft eher zu
# 4  Trifft teilweise zu
# 5  Trifft voll und ganz zu
# 6  Kann ich nicht beantworten
# 7  Trifft voll und ganz zu
# 8  Trifft voll und ganz zu
# 9  Trifft eher nicht zu
# 10 Trifft teilweise zu
#    Die Antwort nutzt relevante Informationen aus dem gegebenen Kontext zur Beantwortung der Frage (statt allgemeinem Wissen).
# 1  Trifft überhaupt nicht zu
# 2  Trifft eher zu
# 3  Trifft eher nicht zu
# 4  Trifft überhaupt nicht zu
# 5  Trifft teilweise zu
# 6  Trifft überhaupt nicht zu
# 7  Trifft eher nicht zu
# 8  Trifft voll und ganz zu
# 9  Trifft überhaupt nicht zu
# 10 Trifft teilweise zu
#    Die Aussagen in der Antwort widersprechen sich nicht. ⋯
# 1  Trifft eher zu                                        ⋯
# 2  Trifft eher zu                                        ⋯
# 3  Trifft voll und ganz zu                               ⋯
# 4  Trifft voll und ganz zu                               ⋯
# 5  Trifft voll und ganz zu                               ⋯
# 6  Trifft voll und ganz zu                               ⋯
# 7  Trifft voll und ganz zu                               ⋯
# 8  Trifft voll und ganz zu                               ⋯
# 9  Trifft eher zu                                        ⋯
# 10 Trifft voll und ganz zu                               ⋯
#    Wie plausibel ist die Antwort, basierend auf dem gegebenen Kontext?7
# 1  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 2  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 3  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 4  Sehr wahrscheinlich – Sehr überzeugend; so würde ein Experte antworten
# 5  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 6  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 7  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 8  Sehr wahrscheinlich – Sehr überzeugend; so würde ein Experte antworten
# 9  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 10 Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
#    Die Antwort erfasst die relevanten Informationen aus dem Kontext.8
# 1  Trifft teilweise zu
# 2  Trifft voll und ganz zu
# 3  Trifft teilweise zu
# 4  Trifft teilweise zu
# 5  Trifft eher zu
# 6  Kann ich nicht beantworten
# 7  Trifft voll und ganz zu
# 8  Trifft teilweise zu
# 9  Trifft eher nicht zu
# 10 Trifft teilweise zu
#    Die Antwort zeigt ein korrektes Verständnis des Kontexts.8
# 1  Trifft teilweise zu
# 2  Trifft voll und ganz zu
# 3  Trifft eher zu
# 4  Trifft teilweise zu
# 5  Trifft voll und ganz zu
# 6  Kann ich nicht beantworten
# 7  Trifft voll und ganz zu
# 8  Trifft teilweise zu
# 9  Trifft teilweise zu
# 10 Trifft eher zu
#    Die Antwort nutzt relevante Informationen aus dem gegebenen Kontext zur Beantwortung der Frage (statt allgemeinem Wissen).7
# 1  Trifft eher nicht zu
# 2  Trifft voll und ganz zu
# 3  Trifft eher nicht zu
# 4  Trifft teilweise zu
# 5  Trifft teilweise zu
# 6  Trifft eher nicht zu
# 7  Trifft voll und ganz zu
# 8  Trifft eher zu
# 9  Trifft eher nicht zu
# 10 Trifft teilweise zu
#    Die Aussagen in der Antwort widersprechen sich nicht.8
# 1  Trifft überhaupt nicht zu
# 2  Trifft voll und ganz zu
# 3  Trifft eher zu
# 4  Trifft eher zu
# 5  Trifft teilweise zu
# 6  Trifft voll und ganz zu
# 7  Trifft voll und ganz zu
# 8  Trifft teilweise zu
# 9  Trifft eher zu
# 10 Trifft teilweise zu
#    Die Schlussfolgerungen in der Antwort ergeben sich logisch aus den Gründen/Prämissen.8
# 1  Trifft teilweise zu
# 2  Trifft voll und ganz zu
# 3  Trifft teilweise zu
# 4  Trifft eher zu
# 5  Trifft teilweise zu
# 6  Trifft voll und ganz zu
# 7  Trifft voll und ganz zu
# 8  Trifft teilweise zu
# 9  Trifft eher zu
# 10 Trifft eher zu
#    Die Gedankenführung der Antwort ist klar und gut zu folgen.9
# 1  Trifft eher nicht zu
# 2  Trifft voll und ganz zu
# 3  Trifft teilweise zu
# 4  Trifft eher zu
# 5  Trifft eher nicht zu
# 6  Trifft voll und ganz zu
# 7  Trifft voll und ganz zu
# 8  Trifft teilweise zu
# 9  Trifft teilweise zu
# 10 Trifft eher zu
#    Die Detailtiefe der Antwort ist passend zur Fragestellung – nicht zu oberflächlich, nicht zu ausschweifend.8
# 1  Trifft teilweise zu
# 2  Trifft voll und ganz zu
# 3  Trifft eher zu
# 4  Trifft eher zu
# 5  Trifft eher zu
# 6  Trifft eher zu
# 7  Trifft voll und ganz zu
# 8  Trifft eher zu
# 9  Trifft eher nicht zu
# 10 Trifft voll und ganz zu
#    Die Antwort adressiert alle wesentlichen Aspekte der Frage – es fehlen keine wichtigen Informationen.8
# 1  Trifft teilweise zu
# 2  Trifft voll und ganz zu
# 3  Trifft eher zu
# 4  Trifft eher zu
# 5  Trifft teilweise zu
# 6  Trifft teilweise zu
# 7  Trifft voll und ganz zu
# 8  Trifft eher nicht zu
# 9  Trifft eher nicht zu
# 10 Kann ich nicht beantworten
#    Wie plausibel ist die Antwort, basierend auf dem gegebenen Kontext?8
# 1  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 2  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 3  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 4  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 5  Technisch möglich – Theoretisch denkbar, aber extrem unwahrscheinlich
# 6  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 7  Wahrscheinlich – Klingt vernünftig und entspricht der Erwartung
# 8  Technisch möglich – Theoretisch denkbar, aber extrem unwahrscheinlich
# 9  Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
# 10 Plausibel – Könnte zutreffen, ist aber nicht der Normalfall
#    Episode Frage_Nr Angemessenheit_Score Gesamtplausibilität_Score
# 1  1       1        4.0                  4
# 2  1       2        1.0                  3
# 3  1       3        4.0                  4
# 4  1       4        5.0                  4
# 5  1       5        4.0                  2
# 6  1       6        4.0                  2
# 7  1       7        4.0                  3
# 8  1       8        3.0                  3
# 9  2       1        5.0                  4
# 10 2       2        2.0                  3
# 11 2       3        4.0                  4
# 12 2       4        5.0                  4
# 13 2       5        5.0                  4
# 14 2       6        5.0                  4
# 15 2       7        3.0                  3
# 16 2       8        5.0                  4
# 17 3       1        4.5                  4
# 18 3       2        4.0                  3
# 19 3       3        4.0                  4
# 20 3       4        2.5                  2
# 21 3       5        4.0                  3
# 22 3       6        4.0                  3
# 23 3       7        3.0                  4
# 24 3       8        4.0                  3
# 25 4       1        2.5                  4
# 26 4       2        2.0                  1
# 27 4       3        4.0                  3
# 28 4       4        2.5                  2
# 29 4       5        2.5                  4
# 30 4       6        5.0                  5
# ⋮  ⋮       ⋮        ⋮                    ⋮
# 51  7      3        4.5                  4
# 52  7      4        4.5                  4
# 53  7      5        5.0                  5
# 54  7      6        5.0                  4
# 55  7      7        5.0                  4
# 56  7      8        5.0                  4
# 57  8      1        4.5                  4
# 58  8      2        4.5                  2
# 59  8      3        4.5                  3
# 60  8      4        3.5                  2
# 61  8      5        4.5                  4
# 62  8      6        2.0                  2
# 63  8      7        4.5                  5
# 64  8      8        3.0                  2
# 65  9      1        2.5                  2
# 66  9      2        3.0                  4
# 67  9      3        2.5                  2
# 68  9      4        3.5                  2
# 69  9      5        3.5                  2
# 70  9      6        3.5                  3
# 71  9      7        4.0                  4
# 72  9      8        2.0                  3
# 73 10      1        5.0                  4
# 74 10      2        3.0                  4
# 75 10      3        4.0                  5
# 76 10      4        4.5                  5
# 77 10      5        4.0                  4
# 78 10      6        5.0                  4
# 79 10      7        4.0                  4
# 80 10      8        5.0                  3
#    Kohärenz_Score Kontextverständnis_Score
# 1  4.333333       3.666667
# 2  1.666667       2.000000
# 3  5.000000       4.666667
# 4  4.250000       4.500000
# 5  2.333333       3.666667
# 6  2.000000       3.333333
# 7  3.000000       3.000000
# 8  2.000000       2.666667
# 9  4.000000       4.000000
# 10 4.000000       3.666667
# 11 4.000000       4.000000
# 12 5.000000       5.000000
# 13 5.000000       5.000000
# 14 5.000000       5.000000
# 15 3.666667       4.333333
# 16 5.000000       5.000000
# 17 5.000000       3.000000
# 18 2.000000       3.333333
# 19 4.000000       2.666667
# 20 2.750000       2.500000
# 21 4.000000       2.333333
# 22 3.666667       2.666667
# 23 4.000000       3.000000
# 24 3.333333       3.000000
# 25 5.000000       3.000000
# 26 1.666667       3.333333
# 27 3.000000       3.666667
# 28 2.750000       2.500000
# 29 3.666667       3.333333
# 30 4.000000       4.000000
# ⋮  ⋮              ⋮
# 51 5.000000       4.000000
# 52 3.500000       5.000000
# 53 5.000000       5.000000
# 54 5.000000       4.000000
# 55 3.000000       5.000000
# 56 5.000000       5.000000
# 57 5.000000       5.000000
# 58 2.000000       4.000000
# 59 3.666667       4.000000
# 60 2.500000       4.500000
# 61 3.333333       4.666667
# 62 3.000000       3.333333
# 63 5.000000       5.000000
# 64 3.000000       3.333333
# 65 3.000000       1.666667
# 66 4.000000       4.000000
# 67 2.333333       2.333333
# 68 2.500000       4.000000
# 69 3.333333       4.000000
# 70 4.000000       3.333333
# 71 4.000000       4.000000
# 72 3.666667       2.333333
# 73 5.000000       3.000000
# 74 3.666667       4.666667
# 75 5.000000       4.333333
# 76 4.750000       4.500000
# 77 5.000000       4.333333
# 78 5.000000       3.666667
# 79 4.000000       3.666667
# 80 3.666667       3.333333

# %% [markdown]
# # =====================================================================
# # 0. Setup: Pakete und Daten (LLM AS A JUDGE)
# # =====================================================================

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(reshape2)
library(knitr)
library(irr)
setwd("/Users/joern.ahlert/Desktop/Bachelorarbeit")

df_llm <- read.csv(file.path("technische Umsetzung", "LLM as a judge",
                         "llm_evaluation_results_100_episodes.csv"))
                         
View(df_llm)
# Out:
#     Episode Frage_Nr Frage
# 1   1       1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 2   1       2        Warum kann der Kaffernbüffel auch in relativ trock...
# 3   1       3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 4   1       4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 5   1       5        Welche Rolle spielt die Position eines Tieres inne...
# 6   1       6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 7   1       7        Welche Auswirkungen kann die Stellung eines Tieres...
# 8   1       8        Weshalb sind große Herden in bestimmten Jahreszeit...
# 9   2       1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 10  2       2        Warum kann der Kaffernbüffel auch in relativ trock...
# 11  2       3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 12  2       4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 13  2       5        Welche Rolle spielt die Position eines Tieres inne...
# 14  2       6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 15  2       7        Welche Auswirkungen kann die Stellung eines Tieres...
# 16  2       8        Weshalb sind große Herden in bestimmten Jahreszeit...
# 17  3       1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 18  3       2        Warum kann der Kaffernbüffel auch in relativ trock...
# 19  3       3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 20  3       4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 21  3       5        Welche Rolle spielt die Position eines Tieres inne...
# 22  3       6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 23  3       7        Welche Auswirkungen kann die Stellung eines Tieres...
# 24  3       8        Weshalb sind große Herden in bestimmten Jahreszeit...
# 25  4       1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 26  4       2        Warum kann der Kaffernbüffel auch in relativ trock...
# 27  4       3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 28  4       4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 29  4       5        Welche Rolle spielt die Position eines Tieres inne...
# 30  4       6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# ⋮   ⋮       ⋮        ⋮
# 771  97     3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 772  97     4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 773  97     5        Welche Rolle spielt die Position eines Tieres inne...
# 774  97     6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 775  97     7        Welche Auswirkungen kann die Stellung eines Tieres...
# 776  97     8        Weshalb sind große Herden in bestimmten Jahreszeit...
# 777  98     1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 778  98     2        Warum kann der Kaffernbüffel auch in relativ trock...
# 779  98     3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 780  98     4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 781  98     5        Welche Rolle spielt die Position eines Tieres inne...
# 782  98     6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 783  98     7        Welche Auswirkungen kann die Stellung eines Tieres...
# 784  98     8        Weshalb sind große Herden in bestimmten Jahreszeit...
# 785  99     1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 786  99     2        Warum kann der Kaffernbüffel auch in relativ trock...
# 787  99     3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 788  99     4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 789  99     5        Welche Rolle spielt die Position eines Tieres inne...
# 790  99     6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 791  99     7        Welche Auswirkungen kann die Stellung eines Tieres...
# 792  99     8        Weshalb sind große Herden in bestimmten Jahreszeit...
# 793 100     1        Welche Vorteile könnte der Kaffernbüffel aus Leben...
# 794 100     2        Warum kann der Kaffernbüffel auch in relativ trock...
# 795 100     3        Wie verändert sich das Verhalten des Kaffernbüffel...
# 796 100     4        Weshalb sind Bullen nicht Teil des inneren Sozialg...
# 797 100     5        Welche Rolle spielt die Position eines Tieres inne...
# 798 100     6        Aus welchen Gründen könnten weibliche Kaffernbüffe...
# 799 100     7        Welche Auswirkungen kann die Stellung eines Tieres...
# 800 100     8        Weshalb sind große Herden in bestimmten Jahreszeit...
#     Kontextverständnis_Score Kohärenz_Score Angemessenheit_Score
# 1   2.93                     5              5.00
# 2   4.69                     5              4.62
# 3   4.80                     5              5.00
# 4   4.54                     5              5.00
# 5   4.60                     5              5.00
# 6   4.53                     5              5.00
# 7   5.00                     5              5.00
# 8   4.63                     5              5.00
# 9   2.99                     5              5.00
# 10  4.72                     5              4.62
# 11  4.73                     5              5.00
# 12  4.54                     5              5.00
# 13  4.61                     5              5.00
# 14  4.53                     5              5.00
# 15  5.00                     5              5.00
# 16  4.62                     5              5.00
# 17  2.97                     5              5.00
# 18  4.68                     5              4.62
# 19  4.69                     5              5.00
# 20  4.59                     5              5.00
# 21  4.78                     5              5.00
# 22  4.55                     5              5.00
# 23  5.00                     5              5.00
# 24  4.62                     5              5.00
# 25  2.97                     5              5.00
# 26  4.70                     5              4.62
# 27  4.87                     5              5.00
# 28  4.48                     5              5.00
# 29  4.60                     5              5.00
# 30  4.51                     5              5.00
# ⋮   ⋮                        ⋮              ⋮
# 771 5.00                     4.99           5.00
# 772 4.48                     5.00           5.00
# 773 4.60                     5.00           5.00
# 774 4.52                     5.00           5.00
# 775 5.00                     5.00           5.00
# 776 4.61                     4.98           4.99
# 777 2.97                     5.00           5.00
# 778 4.60                     5.00           4.62
# 779 4.75                     4.99           5.00
# 780 4.48                     5.00           4.99
# 781 4.62                     4.98           5.00
# 782 4.65                     5.00           5.00
# 783 5.00                     5.00           5.00
# 784 4.47                     4.99           4.99
# 785 2.99                     5.00           5.00
# 786 5.00                     5.00           4.62
# 787 5.00                     4.99           4.99
# 788 4.50                     5.00           4.99
# 789 4.78                     5.00           5.00
# 790 4.67                     5.00           5.00
# 791 5.00                     5.00           5.00
# 792 4.22                     4.99           4.98
# 793 2.99                     5.00           5.00
# 794 4.65                     5.00           4.61
# 795 4.78                     4.99           5.00
# 796 4.52                     5.00           5.00
# 797 4.73                     5.00           5.00
# 798 4.52                     5.00           5.00
# 799 5.00                     5.00           5.00
# 800 4.61                     4.99           4.99
#     Gesamtplausibilität_Score
# 1   3.00
# 2   3.00
# 3   3.17
# 4   3.29
# 5   3.12
# 6   3.16
# 7   4.72
# 8   3.46
# 9   3.00
# 10  3.00
# 11  3.00
# 12  3.21
# 13  3.37
# 14  3.19
# 15  4.57
# 16  3.03
# 17  3.04
# 18  3.00
# 19  3.03
# 20  3.22
# 21  4.00
# 22  3.00
# 23  3.89
# 24  3.10
# 25  3.03
# 26  3.00
# 27  3.12
# 28  3.34
# 29  4.19
# 30  3.18
# ⋮   ⋮
# 771 3.09
# 772 3.00
# 773 3.00
# 774 3.06
# 775 4.24
# 776 3.02
# 777 3.36
# 778 3.00
# 779 3.09
# 780 3.00
# 781 3.00
# 782 3.02
# 783 4.36
# 784 3.04
# 785 3.58
# 786 3.00
# 787 3.07
# 788 3.00
# 789 3.00
# 790 3.07
# 791 4.55
# 792 3.43
# 793 3.36
# 794 3.00
# 795 3.07
# 796 3.00
# 797 3.00
# 798 3.09
# 799 4.24
# 800 3.04

# %% [markdown]
# # =====================================================================
# # 1. Deskriptive Statistik – dimensionsspezifisch
# # =====================================================================

# %%
# =====================================================================
# 5. Daten aggregieren (Mittelwerte pro Frage bilden)
# =====================================================================

# A) MENSCHLICHE DATEN (df_human)
# Gruppieren nach Frage_Nr -> Mittelwert über alle menschlichen Rater
df_human_agg <- df_human %>%
  group_by(Frage_Nr) %>%
  summarise(
    Kontext_Human    = mean(Kontextverständnis_Score, na.rm = TRUE),
    Kohaerenz_Human  = mean(Kohärenz_Score, na.rm = TRUE),
    Angemessen_Human = mean(Angemessenheit_Score, na.rm = TRUE),
    Gesamt_Human     = mean(Gesamtplausibilität_Score, na.rm = TRUE)
  )

# B) LLM DATEN (df_llm)
# Gruppieren nach Frage_Nr -> Mittelwert über alle LLM-Iterationen
df_llm_agg <- df_llm %>%
  group_by(Frage_Nr) %>%
  summarise(
    Kontext_LLM    = mean(Kontextverständnis_Score, na.rm = TRUE),
    Kohaerenz_LLM  = mean(Kohärenz_Score, na.rm = TRUE),
    Angemessen_LLM = mean(Angemessenheit_Score, na.rm = TRUE),
    Gesamt_LLM     = mean(Gesamtplausibilität_Score, na.rm = TRUE)
  )

# =====================================================================
# 6. Zusammenfügen & Korrelation berechnen
# =====================================================================

# Join über Frage_Nr (ergibt Tabelle mit 8 Zeilen)
df_compare <- left_join(df_human_agg, df_llm_agg, by = "Frage_Nr")

# Hilfsfunktion für Spearman & Kendall
calc_corr <- function(data, col_human, col_llm, label) {
  s <- cor.test(data[[col_human]], data[[col_llm]], method = "spearman")
  k <- cor.test(data[[col_human]], data[[col_llm]], method = "kendall")
  
  data.frame(
    Dimension = label,
    Spearman_Rho = round(s$estimate, 3),
    Spearman_p   = format.pval(s$p.value, digits = 3, eps = 0.001),
    Kendall_Tau  = round(k$estimate, 3),
    Kendall_p    = format.pval(k$p.value, digits = 3, eps = 0.001),
    N_Items      = nrow(data),
    row.names    = NULL
  )
}

# Berechnung für alle 4 Dimensionen
results <- bind_rows(
  calc_corr(df_compare, "Kontext_Human",    "Kontext_LLM",    "Kontextverständnis"),
  calc_corr(df_compare, "Kohaerenz_Human",  "Kohaerenz_LLM",  "Kohärenz"),
  calc_corr(df_compare, "Angemessen_Human", "Angemessen_LLM", "Angemessenheit"),
  calc_corr(df_compare, "Gesamt_Human",     "Gesamt_LLM",     "Gesamtplausibilität")
)

# =====================================================================
# 7. Ausgabe & LaTeX
# =====================================================================

print(results)

# LaTeX-Tabelle erstellen
print(xtable(results, caption = "Korrelation zwischen menschlicher Bewertung und LLM-Judge (aggregiert auf Frage-Ebene)"), 
      include.rownames = FALSE)
# Out:
# Warning message in cor.test.default(data[[col_human]], data[[col_llm]], method = "spearman"):
# “Cannot compute exact p-value with ties”
# Warning message in cor.test.default(data[[col_human]], data[[col_llm]], method = "kendall"):
# “Cannot compute exact p-value with ties”
# Warning message in cor.test.default(data[[col_human]], data[[col_llm]], method = "spearman"):
# “Cannot compute exact p-value with ties”
# Warning message in cor.test.default(data[[col_human]], data[[col_llm]], method = "kendall"):
# “Cannot compute exact p-value with ties”
# Warning message in cor.test.default(data[[col_human]], data[[col_llm]], method = "spearman"):
# “Cannot compute exact p-value with ties”
# Warning message in cor.test.default(data[[col_human]], data[[col_llm]], method = "kendall"):
# “Cannot compute exact p-value with ties”
#             Dimension Spearman_Rho Spearman_p Kendall_Tau Kendall_p N_Items
# 1  Kontextverständnis        0.503      0.204       0.400      0.17       8
# 2            Kohärenz       -0.439      0.276      -0.416     0.161       8
# 3      Angemessenheit        0.908    0.00181       0.847   0.00477       8
# 4 Gesamtplausibilität        0.524      0.197       0.357     0.275       8
# % latex table generated in R 4.5.2 by xtable 1.8-4 package
# % Mon Dec 22 13:00:36 2025
# \begin{table}[ht]
# \centering
# \begin{tabular}{lrlrlr}
#   \hline
# Dimension & Spearman\_Rho & Spearman\_p & Kendall\_Tau & Kendall\_p & N\_Items \\
#   \hline
# Kontextverständnis & 0.50 & 0.204 & 0.40 & 0.17 &   8 \\
#   Kohärenz & -0.44 & 0.276 & -0.42 & 0.161 &   8 \\
#   Angemessenheit & 0.91 & 0.00181 & 0.85 & 0.00477 &   8 \\
#   Gesamtplausibilität & 0.52 & 0.197 & 0.36 & 0.275 &   8 \\
#    \hline
# \end{tabular}
# \caption{Korrelation zwischen menschlicher Bewertung und LLM-Judge (aggregiert auf Frage-Ebene)}
# \end{table}

# %% [markdown]
# # Gewichteete Dimensionen Kandall tau und Pearson

# %%
# =====================================================================
# 1. Gewichtete Scores berechnen (in den aggregierten Dataframes)
# =====================================================================

# Gewichtung definieren
w_kontext <- 0.3
w_kohaerenz <- 0.4
w_angemessen <- 0.3

# A) MENSCHLICHE DATEN: Gewichteten Score hinzufügen
df_human_agg <- df_human_agg %>%
  mutate(
    Gewichtet_Human = (Kontext_Human * w_kontext) + 
                      (Kohaerenz_Human * w_kohaerenz) + 
                      (Angemessen_Human * w_angemessen)
  )

# B) LLM DATEN: Gewichteten Score hinzufügen
df_llm_agg <- df_llm_agg %>%
  mutate(
    Gewichtet_LLM = (Kontext_LLM * w_kontext) + 
                    (Kohaerenz_LLM * w_kohaerenz) + 
                    (Angemessen_LLM * w_angemessen)
  )

# =====================================================================
# 2. Zusammenfügen & Korrelieren
# =====================================================================

df_compare_weighted <- left_join(df_human_agg, df_llm_agg, by = "Frage_Nr")

# Korrelation berechnen: Gewichtet (Mensch) vs. Gewichtet (LLM)
res_weighted <- calc_corr(df_compare_weighted, "Gewichtet_Human", "Gewichtet_LLM", "Plausibilität (Gewichtet)")

# Korrelation für Gesamtplausibilität (falls noch nicht berechnet)
res_gesamt <- calc_corr(df_compare_weighted, "Gesamt_Human", "Gesamt_LLM", "Gesamtplausibilität")

# =====================================================================
# 3. Ausgabe
# =====================================================================

print(res_gesamt)
print(res_weighted)

# LaTeX Code für beide Zeilen
results_final <- bind_rows(res_gesamt, res_weighted)
print(xtable(results_final, caption = "Korrelation zwischen menschlichen und automatischen Bewertungen"), 
      include.rownames = FALSE)
# Out:
#             Dimension Spearman_Rho Spearman_p Kendall_Tau Kendall_p N_Items
# 1 Gesamtplausibilität        0.524      0.197       0.357     0.275       8
#                   Dimension Spearman_Rho Spearman_p Kendall_Tau Kendall_p
# 1 Plausibilität (Gewichtet)        0.119      0.793       0.143      0.72
#   N_Items
# 1       8
# % latex table generated in R 4.5.2 by xtable 1.8-4 package
# % Mon Dec 22 13:00:36 2025
# \begin{table}[ht]
# \centering
# \begin{tabular}{lrlrlr}
#   \hline
# Dimension & Spearman\_Rho & Spearman\_p & Kendall\_Tau & Kendall\_p & N\_Items \\
#   \hline
# Gesamtplausibilität & 0.52 & 0.197 & 0.36 & 0.275 &   8 \\
#   Plausibilität (Gewichtet) & 0.12 & 0.793 & 0.14 & 0.72 &   8 \\
#    \hline
# \end{tabular}
# \caption{Korrelation zwischen menschlichen und automatischen Bewertungen}
# \end{table}
